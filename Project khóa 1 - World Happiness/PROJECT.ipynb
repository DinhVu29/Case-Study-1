# %%
#Import file vào google colab
from google.colab import files
import pandas as pd
uploaded = files.upload()
# Out:
#      <input type="file" id="files-26fe09db-6382-43e2-9b3a-b5983fc28633" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-26fe09db-6382-43e2-9b3a-b5983fc28633">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
#Đọc file vừa import
df_2020_2021 = pd.read_csv('2020_2021.csv')
df_2020_2022 = pd.read_csv('2020_2022.csv')

# %%
#Tìm giá trị Nan 
nan_2020_2021 = df_2020_2021[df_2020_2021.isna().any(axis=1)]
nan_2020_2021
# Out:
#                  Country_2020     Country_2021
# 93                        NaN  North Macedonia
# 190       Trinidad and Tobago              NaN
# 238                 Macedonia              NaN
# 279          Congo (Kinshasa)              NaN
# 297  Central African Republic              NaN
# 300               South Sudan              NaN

# %%
nan_2020_2022 = df_2020_2022[df_2020_2022.isna().any(axis=1)]
nan_2020_2022
# Out:
#                  Country_2020              Country_2022
# 5                         NaN               Luxembourg*
# 17                        NaN                   Czechia
# 38                        NaN                Guatemala*
# 49                        NaN                   Kuwait*
# 64                        NaN                  Belarus*
# 77                        NaN             Turkmenistan*
# 78                        NaN             North Cyprus*
# 85                        NaN                    Libya*
# 88                        NaN           North Macedonia
# 91                        NaN               Azerbaijan*
# 92                        NaN                   Gambia*
# 96                        NaN                  Liberia*
# 98                        NaN                     Congo
# 103                       NaN                    Niger*
# 115                       NaN                  Comoros*
# 121                       NaN  Palestinian Territories*
# ...
